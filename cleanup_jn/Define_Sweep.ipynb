# %%
import wandb
import itertools
wandb.login()
# Out:
# wandb: Currently logged in as: toneyan (use `wandb login --relogin` to force relogin)
# True

# %% [markdown]
# # colab

# %%
#/grid/koo/home/toneyan/profile/QuantPred/datasets/colab

sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
          'value': '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/i_3072_w_1/'
    },
    'model_fn':{
        'values': ['bpnet', 'basenji_w1_b64', 'residual_profile_task_base']
    },
    'loss_fn':{
        'value': 'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'value': 1
    },
    'l_rate': {
        'value': 0.001
    },
    'epochN': {
        'value': 40
    },
    'activation':{
        'value': 'exponential'
    }
    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="COLAB_MODEL_SELECTION")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/i_3072_w_1/'}, 'model_fn': {'values': ['bpnet', 'basenji_w1_b64', 'residual_profile_task_base']}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'value': 1}, 'l_rate': {'value': 0.001}, 'epochN': {'value': 40}, 'activation': {'value': 'exponential'}}}
# Create sweep with ID: ozfdnxtf
# Sweep URL: https://wandb.ai/toneyan/COLAB_MODEL_SELECTION/sweeps/ozfdnxtf

# %%
#/grid/koo/home/toneyan/profile/QuantPred/datasets/colab

sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
          'value': '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/i_3072_w_1/'
    },
    'model_fn':{
        'values': ['bpnet', 'mod_basenji', 'residual_profile_all_dense_32', 'residual_profile_task_conv_32']
    },
    'loss_fn':{
        'value': 'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'value': 32
    },
    'l_rate': {
        'value': 0.001
    },
    'epochN': {
        'value': 40
    },
    'activation':{
        'value': 'exponential'
    }
    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="COLAB_MODEL_SELECTION")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/i_3072_w_1/'}, 'model_fn': {'values': ['bpnet', 'mod_basenji', 'residual_profile_all_dense_32', 'residual_profile_task_conv_32']}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'value': 32}, 'l_rate': {'value': 0.001}, 'epochN': {'value': 40}, 'activation': {'value': 'exponential'}}}
# Create sweep with ID: ziovko1v
# Sweep URL: https://wandb.ai/toneyan/COLAB_MODEL_SELECTION/sweeps/ziovko1v

# %%
# test datasets

sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
          'values': ['/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/WHOLE/i_3072_w_1/',
                    '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/NOCTR/i_3072_w_1/',
                    '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/DD2/i_3072_w_1/',
                    '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/DD5/i_3072_w_1/',
                    '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/BalbC/i_3072_w_1/']
    },
    'model_fn':{
        'values': ['residual_profile_task_base']
    },
    'loss_fn':{
        'value': 'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'value': 1
    },
    'l_rate': {
        'value': 0.001
    },
    'epochN': {
        'value': 40
    },
    'activation':{
        'value': 'exponential'
    }
    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="COLAB_DATASET_SELECTION")



#/grid/koo/home/toneyan/profile/QuantPred/datasets/colab

sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
          'values': ['/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/WHOLE/i_3072_w_1/',
                    '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/NOCTR/i_3072_w_1/',
                    '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/DD2/i_3072_w_1/',
                    '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/DD5/i_3072_w_1/',
                    '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/BalbC/i_3072_w_1/']
    },
    'model_fn':{
        'values': ['residual_profile_all_dense_32']
    },
    'loss_fn':{
        'value': 'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'value': 32
    },
    'l_rate': {
        'value': 0.001
    },
    'epochN': {
        'value': 40
    },
    'activation':{
        'value': 'exponential'
    }
    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="COLAB_DATASET_SELECTION")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'values': ['/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/WHOLE/i_3072_w_1/', '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/NOCTR/i_3072_w_1/', '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/DD2/i_3072_w_1/', '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/DD5/i_3072_w_1/', '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/BalbC/i_3072_w_1/']}, 'model_fn': {'values': ['residual_profile_task_base']}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'value': 1}, 'l_rate': {'value': 0.001}, 'epochN': {'value': 40}, 'activation': {'value': 'exponential'}}}
# Create sweep with ID: t10jeuzc
# Sweep URL: https://wandb.ai/toneyan/COLAB_DATASET_SELECTION/sweeps/t10jeuzc
# ...

# %%
#/grid/koo/home/toneyan/profile/QuantPred/datasets/colab

sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
          'value': '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/i_3072_w_1/'
    },
    'model_fn':{
        'values': ['basenjimod']
    },
    'loss_fn':{
        'value': 'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'value': 32
    },
    'l_rate': {
        'value': 0.001
    },
    'epochN': {
        'value': 40
    },
    'activation':{
        'value': 'exponential'
    }
    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="COLAB_MODEL_SELECTION")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': '/grid/koo/home/toneyan/profile/QuantPred/datasets/colab/i_3072_w_1/'}, 'model_fn': {'values': ['basenjimod']}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'value': 32}, 'l_rate': {'value': 0.001}, 'epochN': {'value': 40}, 'activation': {'value': 'exponential'}}}
# Create sweep with ID: l6hgiil1
# Sweep URL: https://wandb.ai/toneyan/COLAB_MODEL_SELECTION/sweeps/l6hgiil1

# %% [markdown]
# # bpnet

# %%
sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
#         'value': '/home/shush/profile/QuantPred/datasets/ATAC_v3/i_3072_w_1/'
          'value': '/home/shush/profile/QuantPred/datasets/ATAC_v4/i_3072_w_1/'
    },
    'model_fn':{
        'value': 'bpnet'
    },
    'loss_fn':{
        'value': 'multinomialnll'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'value': 1
    },
    'l_rate': {
        'value': 0.001
    },
    'epochN': {
        'value': 30
    },
    'filtN_1': {
        'values': [64, 128]
    },
    'filtN_2': {
        'values': [64, 128, 256]
    },
#     'filtN_3': {
#         'values': [32,64,128]
#     },
#     'filtN_4': {
#         'values': [32,64,128]
#     },
    'kern_3': {
        'values': [7, 17, 25]
    },
#     'kern_2': {
#         'values': [3, 8]
#     },    

    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="tune_bpnet_debug")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': '/home/shush/profile/QuantPred/datasets/ATAC_v4/i_3072_w_1/'}, 'model_fn': {'value': 'bpnet'}, 'loss_fn': {'value': 'multinomialnll'}, 'window_size': {'value': 2048}, 'bin_size': {'value': 1}, 'l_rate': {'value': 0.001}, 'epochN': {'value': 30}, 'filtN_1': {'values': [64, 128]}, 'filtN_2': {'values': [64, 128, 256]}, 'kern_3': {'values': [7, 17, 25]}}}
# Create sweep with ID: smuqb1k1
# Sweep URL: https://wandb.ai/toneyan/tune_bpnet_debug/sweeps/smuqb1k1

# %%
sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
#         'value': '/home/shush/profile/QuantPred/datasets/ATAC_v3/i_3072_w_1/'
          'value': '/home/shush/profile/QuantPred/datasets/ATAC_v4/i_3072_w_1/'
    },
    'model_fn':{
        'value': 'basenjimod'
    },
    'loss_fn':{
        'value': 'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'value': 128
    },
    'l_rate': {
        'value': 0.001
    },
    'epochN': {
        'value': 30
    },
    'filtN_1': {
        'values': [64, 128]
    },
    'filtN_2': {
        'values': [64, 128, 256]
    },
#     'filtN_3': {
#         'values': [32,64,128]
#     },
#     'filtN_4': {
#         'values': [32,64,128]
#     },
    'kern_3': {
        'values': [7, 17, 25]
    },
#     'kern_2': {
#         'values': [3, 8]
#     },    

    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="tune_basenji_debug")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': '/home/shush/profile/QuantPred/datasets/ATAC_v4/i_3072_w_1/'}, 'model_fn': {'value': 'basenjimod'}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'value': 128}, 'l_rate': {'value': 0.001}, 'epochN': {'value': 30}, 'filtN_1': {'values': [64, 128]}, 'filtN_2': {'values': [64, 128, 256]}, 'kern_3': {'values': [7, 17, 25]}}}
# Create sweep with ID: ooadnkpx
# Sweep URL: https://wandb.ai/toneyan/tune_basenji_debug/sweeps/ooadnkpx

# %%
sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'value': '/home/shush/profile/QuantPred/datasets/ATAC_v4/i_3072_w_1/'
    },
    'model_fn':{
        'value': 'ori_bpnet'
    },
    'loss_fn':{
        'value': 'multinomialnll_mse'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'value': 1
    },
    'l_rate': {
        'value': 0.001
    },
    'epochN': {
        'value': 30
    },
    'filtN_1': {
        'values': [64, 128]
    },
    'filtN_2': {
        'values': [64, 128, 256]
    },
#     'filtN_3': {
#         'values': [32,64,128]
#     },
#     'filtN_4': {
#         'values': [32,64,128]
#     },
    'kern_3': {
        'values': [7, 17, 25]
    },
#     'kern_2': {
#         'values': [3, 8]
#     },    

    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="tune_ori_bpnet")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': '/home/shush/profile/QuantPred/datasets/ATAC_v4/i_3072_w_1/'}, 'model_fn': {'value': 'ori_bpnet'}, 'loss_fn': {'value': 'multinomialnll_mse'}, 'window_size': {'value': 2048}, 'bin_size': {'value': 1}, 'l_rate': {'value': 0.001}, 'epochN': {'value': 30}, 'filtN_1': {'values': [64, 128]}, 'filtN_2': {'values': [64, 128, 256]}, 'kern_3': {'values': [7, 17, 25]}}}
# Create sweep with ID: ix6r9384
# Sweep URL: https://wandb.ai/toneyan/tune_ori_bpnet/sweeps/ix6r9384

# %% [markdown]
# # basenji

# %%
filtN_1 = [64, 128]
filtN_2 = [64, 128, 256]
filtN_4 = [64, 128, 256]
filtN_5 = [64, 128, 256, 512, 1024]

all_combs = list(itertools.product(*[filtN_1, filtN_2, filtN_4, filtN_5]))

good_combs = []
for comb in all_combs:
    if all(i <= j for i, j in zip(comb, comb[1:])):
        good_combs.append(comb)

# %%
sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'value': '/home/shush/profile/QuantPred/datasets/ATAC_v3/i_3072_w_1/'
    },
    'model_fn':{
        'value': 'basenjimod'
    },
    'loss_fn':{
        'value': 'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'value': 128
    },
    'l_rate': {
        'value': 0.001
    },
    'epochN': {
        'value': 30
    },
    'filtN_list': {
        'values': good_combs
    },
    'drp_off': {
        'values': [False, True]
    }
#     'filtN_1': {
#         'values': [64, 128]
#     },
#     'filtN_2': {
#         'values': [32, 64, 128]
#     },
#     'filtN_3': {
#         'values': [32,64,128]
#     },
#     'filtN_4': {
#         'values': [32,64,128]
#     },
#     'kern_1': {
#         'values': [5, 15, 25]
#     },
#     'kern_2': {
#         'values': [3, 8]
#     },    
#     'filt_mlt': {
#         'values': [1.125, 2]
#     }
    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="tune_basenji")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': '/home/shush/profile/QuantPred/datasets/ATAC_v3/i_3072_w_1/'}, 'model_fn': {'value': 'basenjimod'}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'value': 128}, 'l_rate': {'value': 0.001}, 'epochN': {'value': 30}, 'filtN_list': {'values': [(64, 64, 64, 64), (64, 64, 64, 128), (64, 64, 64, 256), (64, 64, 64, 512), (64, 64, 64, 1024), (64, 64, 128, 128), (64, 64, 128, 256), (64, 64, 128, 512), (64, 64, 128, 1024), (64, 64, 256, 256), (64, 64, 256, 512), (64, 64, 256, 1024), (64, 128, 128, 128), (64, 128, 128, 256), (64, 128, 128, 512), (64, 128, 128, 1024), (64, 128, 256, 256), (64, 128, 256, 512), (64, 128, 256, 1024), (64, 256, 256, 256), (64, 256, 256, 512), (64, 256, 256, 1024), (128, 128, 128, 128), (128, 128, 128, 256), (128, 128, 128, 512), (128, 128, 128, 1024), (128, 128, 256, 256), (128, 128, 256, 512), (128, 128, 256, 1024), (128, 256, 2
# ...

# %%
len(good_combs)
# Out:
# 32
