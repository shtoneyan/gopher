# %%
import wandb
import itertools, os
wandb.login()
# Out:
# wandb: Currently logged in as: toneyan (use `wandb login --relogin` to force relogin)
# True

# %% [markdown]
# # basenjimod finetune

# %%
filtN_1 = [64, 128]
filtN_2 = [64, 128, 256]
filtN_4 = [64, 128, 256]
filtN_5 = [64, 128, 256, 512, 1024]

sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'value': 'datasets/complete/random_chop/i_3072_w_1/'
    },
    'model_fn':{
        'value': 'basenjimod'
    },
    'loss_fn':{
        'value': 'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'value': 128
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 40
    },
    'add_dropout': {
        'values': [False, True]
    },
    'filtN_1': {
        'values': filtN_1
    },
    'filtN_2': {
        'values': filtN_2
    },
    'filtN_4': {
        'values': filtN_4
    },
    'filtN_5': {
        'values': filtN_5
    }
    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="FINETUNE_BASENJI_128_POISSON_AUGM_E40")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': 'datasets/complete/random_chop/i_3072_w_1/'}, 'model_fn': {'value': 'basenjimod'}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'value': 128}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 40}, 'add_dropout': {'values': [False, True]}, 'filtN_1': {'values': [64, 128]}, 'filtN_2': {'values': [64, 128, 256]}, 'filtN_4': {'values': [64, 128, 256]}, 'filtN_5': {'values': [64, 128, 256, 512, 1024]}}}
# Create sweep with ID: pycox38b
# Sweep URL: https://wandb.ai/toneyan/FINETUNE_BASENJI_128_POISSON_AUGM_E40/sweeps/pycox38b

# %% [markdown]
# # basenji base resolution finetune (bottleneck = 64)

# %%
filtN_1 = [64, 128]
filtN_2 = [64, 128, 256]
filtN_3 = [64, 128, 256]
filtN_4 = [64, 128, 256]
filtN_5 = [64, 128, 256, 512, 1024]

sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'value': 'datasets/complete/random_chop/i_3072_w_1/'
    },
    'model_fn':{
        'value': 'basenji_w1_b64'
    },
    'loss_fn':{
        'value': 'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'value': 1
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 40
    },
    'add_dropout': {
        'values': [False, True]
    },
    'filtN_1': {
        'values': filtN_1
    },
    'filtN_2': {
        'values': filtN_2
    },
    'filtN_3':{
        'values': filtN_3
    },
    'filtN_4': {
        'values': filtN_4
    },
    'filtN_5': {
        'values': filtN_5
    }
    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="FINETUNE_BASENJIW1b64_POISSON_AUGM_E40")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': 'datasets/complete/random_chop/i_3072_w_1/'}, 'model_fn': {'value': 'basenji_w1_b64'}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'value': 1}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 40}, 'add_dropout': {'values': [False, True]}, 'filtN_1': {'values': [64, 128]}, 'filtN_2': {'values': [64, 128, 256]}, 'filtN_3': {'values': [64, 128, 256]}, 'filtN_4': {'values': [64, 128, 256]}, 'filtN_5': {'values': [64, 128, 256, 512, 1024]}}}
# Create sweep with ID: 6c2mqhnm
# Sweep URL: https://wandb.ai/toneyan/FINETUNE_BASENJIW1b64_POISSON_AUGM_E40/sweeps/6c2mqhnm

# %% [markdown]
# # basenji base resolution bottleneck size

# %%
sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
#         'value': '/mnt/1a18a49e-9a31-4dbf-accd-3fb8abbfab2d/shush/4grid_atac/lite/random_chop/i_3072_w_1/'
        'value': 'datasets/complete/random_chop/i_3072_w_1/'
    },
    'model_fn':{
        'values': ['basenji_w1_b64', 'basenji_w1_b128', 'basenji_w1_b256']
    },
    'loss_fn':{
        'value': 'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'value': 1
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    }
    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="BASENJI_BASE_RES_BOTTLENECK")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': 'datasets/complete/random_chop/i_3072_w_1/'}, 'model_fn': {'values': ['basenji_w1_b64', 'basenji_w1_b128', 'basenji_w1_b256']}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'value': 1}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 100}}}
# Create sweep with ID: tx2ja27v
# Sweep URL: https://wandb.ai/toneyan/BASENJI_BASE_RES_BOTTLENECK/sweeps/tx2ja27v

# %% [markdown]
# # bin loss experiment

# %%
# MSE + pearson R loss
sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
#         'value': '/mnt/1a18a49e-9a31-4dbf-accd-3fb8abbfab2d/shush/4grid_atac/lite/random_chop/i_3072_w_1/'
        'value': 'datasets/complete/random_chop/i_3072_w_1/'
    },
    'model_fn':{
        'values': ['basenjimod']
    },
    'loss_fn':{
        'values': ['poisson', 'multinomialnll_mse_reg', 'mse', 
                   'basenjipearsonr', 'pearsonr_mse']
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [32, 64, 128, 512, 1024, 2048]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    }
    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="BASENJI_BIN_LOSS")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': 'datasets/complete/random_chop/i_3072_w_1/'}, 'model_fn': {'values': ['basenjimod']}, 'loss_fn': {'values': ['poisson', 'multinomialnll_mse_reg', 'mse', 'basenjipearsonr', 'pearsonr_mse']}, 'window_size': {'value': 2048}, 'bin_size': {'values': [32, 64, 128, 512, 1024, 2048]}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 100}}}
# Create sweep with ID: qw26qpzn
# Sweep URL: https://wandb.ai/toneyan/BASENJI_BIN_LOSS/sweeps/qw26qpzn

# %%
# FORGOT TO INCLUDE 256
sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
#         'value': '/mnt/1a18a49e-9a31-4dbf-accd-3fb8abbfab2d/shush/4grid_atac/lite/random_chop/i_3072_w_1/'
        'value': 'datasets/complete/random_chop/i_3072_w_1/'
    },
    'model_fn':{
        'values': ['basenjimod']
    },
    'loss_fn':{
        'values': ['poisson', 'multinomialnll_mse_reg', 'mse', 
                   'basenjipearsonr', 'pearsonr_mse']
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [256]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    }
    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="BASENJI_BIN_LOSS")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': 'datasets/complete/random_chop/i_3072_w_1/'}, 'model_fn': {'values': ['basenjimod']}, 'loss_fn': {'values': ['poisson', 'multinomialnll_mse_reg', 'mse', 'basenjipearsonr', 'pearsonr_mse']}, 'window_size': {'value': 2048}, 'bin_size': {'values': [256]}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 100}}}
# Create sweep with ID: igxa7jb7
# Sweep URL: https://wandb.ai/toneyan/BASENJI_BIN_LOSS/sweeps/igxa7jb7

# %%
# MSE + pearson R loss
sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
#         'value': '/mnt/1a18a49e-9a31-4dbf-accd-3fb8abbfab2d/shush/4grid_atac/lite/random_chop/i_3072_w_1/'
        'value': 'datasets/complete/random_chop/i_3072_w_1/'
    },
    'model_fn':{
        'values': ['basenji_w1_b64']
    },
    'loss_fn':{
        'values': ['poisson', 'multinomialnll_mse_reg', 'mse', 
                   'basenjipearsonr', 'pearsonr_mse']
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [1]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    }
    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="BASENJI_BIN_LOSS")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': 'datasets/complete/random_chop/i_3072_w_1/'}, 'model_fn': {'values': ['basenji_w1_b64']}, 'loss_fn': {'values': ['poisson', 'multinomialnll_mse_reg', 'mse', 'basenjipearsonr', 'pearsonr_mse']}, 'window_size': {'value': 2048}, 'bin_size': {'values': [1]}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 100}}}
# Create sweep with ID: l0elh3dq
# Sweep URL: https://wandb.ai/toneyan/BASENJI_BIN_LOSS/sweeps/l0elh3dq

# %%
# MSE + pearson R loss
sweep_config = {
    'method': 'grid'
    }

metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }

sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
#         'value': '/mnt/1a18a49e-9a31-4dbf-accd-3fb8abbfab2d/shush/4grid_atac/lite/random_chop/i_3072_w_1/'
        'value': 'datasets/complete/random_chop/i_3072_w_1/'
    },
    'model_fn':{
        'values': ['basenji_w1_b64']
    },
    'loss_fn':{
        'values': ['multinomialnll_mse_reg']
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [1]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    }
    }

sweep_config['parameters'] = parameters_dict
print(sweep_config)

sweep_id = wandb.sweep(sweep_config, project="TEST")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': 'datasets/complete/random_chop/i_3072_w_1/'}, 'model_fn': {'values': ['basenji_w1_b64']}, 'loss_fn': {'values': ['multinomialnll_mse_reg']}, 'window_size': {'value': 2048}, 'bin_size': {'values': [1]}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 100}}}
# Create sweep with ID: 74orfbl5
# Sweep URL: https://wandb.ai/toneyan/test/sweeps/74orfbl5

# %% [markdown]
# # augmentation
#
# Sweep URL: https://wandb.ai/toneyan/AUGMENTATION_1_128/sweeps/6nc814co
# Sweep URL: https://wandb.ai/toneyan/AUGMENTATION_1_128/sweeps/p5na9tds
# Sweep URL: https://wandb.ai/toneyan/AUGMENTATION_1_128/sweeps/ox567tsd
# Sweep URL: https://wandb.ai/toneyan/AUGMENTATION_1_128/sweeps/4d88hpv7
#
# Sweep URL: https://wandb.ai/toneyan/AUGMENTATION_1_128/sweeps/77jszxxj
# Sweep URL: https://wandb.ai/toneyan/AUGMENTATION_1_128/sweeps/khzlivp8
# Sweep URL: https://wandb.ai/toneyan/AUGMENTATION_1_128/sweeps/ko3q5nv8
# Sweep URL: https://wandb.ai/toneyan/AUGMENTATION_1_128/sweeps/hjfv2eus
#
# Sweep URL: https://wandb.ai/toneyan/AUGMENTATION_1_128/sweeps/ifoa3rtz

# %%
###binned model
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'values':['datasets/complete/peak_centered/i_3072_w_1',
                  'datasets/complete/random_chop/i_3072_w_1']
    },
    'model_fn':{
        'values':['basenjimod']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [128]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    },
    'rev_comp':{
        'values':[True, False]
    },
    'crop':{
        'values':['r_crop']
    }
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="AUGMENTATION_1_128")

### base resolution model
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'values':['datasets/complete/peak_centered/i_3072_w_1',
                  'datasets/complete/random_chop/i_3072_w_1']
    },
    'model_fn':{
        'values':['basenji_w1_b64']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [1]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    },
    'rev_comp':{
        'values':[True, False]
    },
    'crop':{
        'values':['r_crop']
    }
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="AUGMENTATION_1_128")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'values': ['datasets/complete/peak_centered/i_3072_w_1', 'datasets/complete/random_chop/i_3072_w_1']}, 'model_fn': {'values': ['basenjimod']}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'values': [128]}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 100}, 'rev_comp': {'values': [True, False]}, 'crop': {'values': ['r_crop']}}}
# Create sweep with ID: 6nc814co
# Sweep URL: https://wandb.ai/toneyan/AUGMENTATION_1_128/sweeps/6nc814co
# ...

# %%
###binned model
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'values':['datasets/complete/peak_centered/i_2048_w_1',
                  'datasets/complete/random_chop/i_2048_w_1']
    },
    'model_fn':{
        'values':['basenjimod']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [128]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    },
    'rev_comp':{
        'values':[True, False]
    },
    'crop':{
        'values':[False]
    }
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="AUGMENTATION_1_128")

### Base resolution model
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'values':['datasets/complete/peak_centered/i_2048_w_1',
                  'datasets/complete/random_chop/i_2048_w_1']
    },
    'model_fn':{
        'values':['basenji_w1_b64']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [1]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    },
    'rev_comp':{
        'values':[True, False]
    },
    'crop':{
        'values':[False]
    }
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="AUGMENTATION_1_128")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'values': ['datasets/complete/peak_centered/i_2048_w_1', 'datasets/complete/random_chop/i_2048_w_1']}, 'model_fn': {'values': ['basenjimod']}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'values': [128]}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 100}, 'rev_comp': {'values': [True, False]}, 'crop': {'values': [False]}}}
# Create sweep with ID: ox567tsd
# Sweep URL: https://wandb.ai/toneyan/AUGMENTATION_1_128/sweeps/ox567tsd
# ...

# %%
###binned model
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'values':['datasets/complete/peak_centered/i_3072_w_1',
                  'datasets/complete/random_chop/i_3072_w_1']
    },
    'model_fn':{
        'values':['basenjimod']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [128]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    },
    'rev_comp':{
        'values':[True, False]
    },
    'crop':{
        'values':['r_crop']
    }
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="AUGMENTATION_1_128")

### base resolution model
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'values':['datasets/complete/peak_centered/i_3072_w_1',
                  'datasets/complete/random_chop/i_3072_w_1']
    },
    'model_fn':{
        'values':['basenji_w1_b64']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [1]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    },
    'rev_comp':{
        'values':[True, False]
    },
    'crop':{
        'values':['r_crop']
    }
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="AUGMENTATION_1_128")

###binned model
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'values':['datasets/complete/peak_centered/i_2048_w_1',
                  'datasets/complete/random_chop/i_2048_w_1']
    },
    'model_fn':{
        'values':['basenjimod']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [128]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    },
    'rev_comp':{
        'values':[True, False]
    },
    'crop':{
        'values':[False]
    }
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="AUGMENTATION_1_128")

### Base resolution model
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'values':['datasets/complete/peak_centered/i_2048_w_1',
                  'datasets/complete/random_chop/i_2048_w_1']
    },
    'model_fn':{
        'values':['basenji_w1_b64']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [1]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    },
    'rev_comp':{
        'values':[True, False]
    },
    'crop':{
        'values':[False]
    }
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="AUGMENTATION_1_128")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'values': ['datasets/complete/peak_centered/i_3072_w_1', 'datasets/complete/random_chop/i_3072_w_1']}, 'model_fn': {'values': ['basenjimod']}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'values': [128]}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 100}, 'rev_comp': {'values': [True, False]}, 'crop': {'values': ['r_crop']}}}
# Create sweep with ID: 77jszxxj
# Sweep URL: https://wandb.ai/toneyan/AUGMENTATION_1_128/sweeps/77jszxxj
# ...

# %%
# ###binned model
# sweep_config = {
#     'method': 'grid'
#     }
# metric = {
#     'name': 'val_loss',
#     'goal': 'minimize'   
#     }
# sweep_config['metric'] = metric
# parameters_dict = {
#     'data_dir':{
#         'values':['/mnt/1a18a49e-9a31-4dbf-accd-3fb8abbfab2d/shush/4grid_atac/complete/peak_centered/i_3072_w_1',
#                   '/mnt/1a18a49e-9a31-4dbf-accd-3fb8abbfab2d/shush/4grid_atac/complete/random_chop/i_3072_w_1']
#     },
#     'model_fn':{
#         'values':['basenjimod']
#     },
#     'loss_fn':{
#         'value':'poisson'
#     },
#     'window_size':{
#         'value': 2048
#     },
#     'bin_size':{
#         'values': [128]
#     },
#     'l_rate': {
#         'value': 0.001
#     },
#     'num_epochs': {
#         'value': 100
#     },
#     'rev_comp':{
#         'values':[True, False]
#     },
#     'crop':{
#         'values':['r_crop']
#     }
# }
# sweep_config['parameters'] = parameters_dict
# print(sweep_config)
# sweep_id = wandb.sweep(sweep_config, project="AUGMENTATION_1_128")

### base resolution model
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'values':['datasets/complete/peak_centered/i_3072_w_1',
                  'datasets/complete/random_chop/i_3072_w_1']
    },
    'model_fn':{
        'values':['basenji_w1_b64']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [1]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    },
    'rev_comp':{
        'values':[True, False]
    },
    'crop':{
        'values':['r_crop']
    }
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="AUGMENTATION_1_128")

###binned model
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'values':['datasets/complete/peak_centered/i_2048_w_1',
                  'datasets/complete/random_chop/i_2048_w_1']
    },
    'model_fn':{
        'values':['basenjimod']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [128]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    },
    'rev_comp':{
        'values':[True, False]
    },
    'crop':{
        'values':[False]
    }
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="AUGMENTATION_1_128")

### Base resolution model
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'values':['datasets/complete/peak_centered/i_2048_w_1',
                  'datasets/complete/random_chop/i_2048_w_1']
    },
    'model_fn':{
        'values':['basenji_w1_b64']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [1]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    },
    'rev_comp':{
        'values':[True, False]
    },
    'crop':{
        'values':[False]
    }
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="AUGMENTATION_1_128")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'values': ['datasets/complete/peak_centered/i_3072_w_1', 'datasets/complete/random_chop/i_3072_w_1']}, 'model_fn': {'values': ['basenji_w1_b64']}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'values': [1]}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 100}, 'rev_comp': {'values': [True, False]}, 'crop': {'values': ['r_crop']}}}
# Create sweep with ID: kqjmiy02
# Sweep URL: https://wandb.ai/toneyan/AUGMENTATION_1_128/sweeps/kqjmiy02
# ...

# %% [markdown]
# # training set threshold and bin size experiment

# %%
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'values':[
                  'datasets/complete/peak_centered/i_3072_w_1',
                  'datasets/complete/random_chop/i_3072_w_1',
                  'datasets/train_thresholds/threshold_4/i_3072_w_1',
                  'datasets/train_thresholds/threshold_6/i_3072_w_1',
                  'datasets/train_thresholds/threshold_8/i_3072_w_1',
                  'datasets/train_thresholds/threshold_10/i_3072_w_1'
                 ]
    },
    'model_fn':{
        'values': ['basenjimod']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [32, 64, 128, 256, 512, 1024, 2048]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    }
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="BASENJI_TRAINSET_THRESHOLD")


sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'values':[
                  'datasets/complete/peak_centered/i_3072_w_1',
                  'datasets/complete/random_chop/i_3072_w_1',
                  'datasets/train_thresholds/threshold_4/i_3072_w_1',
                  'datasets/train_thresholds/threshold_6/i_3072_w_1',
                  'datasets/train_thresholds/threshold_8/i_3072_w_1',
                  'datasets/train_thresholds/threshold_10/i_3072_w_1'
                 ]
    },
    'model_fn':{
        'values': ['basenji_w1_b64']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [1]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    }
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="BASENJI_TRAINSET_THRESHOLD")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'values': ['datasets/complete/peak_centered/i_3072_w_1', 'datasets/complete/random_chop/i_3072_w_1', 'datasets/train_thresholds/threshold_4/i_3072_w_1', 'datasets/train_thresholds/threshold_6/i_3072_w_1', 'datasets/train_thresholds/threshold_8/i_3072_w_1', 'datasets/train_thresholds/threshold_10/i_3072_w_1']}, 'model_fn': {'values': ['basenjimod']}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'values': [32, 64, 128, 256, 512, 1024, 2048]}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 100}}}
# Create sweep with ID: ephcca34
# Sweep URL: https://wandb.ai/toneyan/BASENJI_TRAINSET_THRESHOLD/sweeps/ephcca34
# ...

# %% [markdown]
# # there was an issue with one of the runs --> rerun here

# %%
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'values':[
                  'datasets/train_thresholds/threshold_8/i_3072_w_1'
                 ]
    },
    'model_fn':{
        'values': ['basenjimod']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'values': [128]
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    }
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="BASENJI_TRAINSET_THRESHOLD")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'values': ['datasets/train_thresholds/threshold_8/i_3072_w_1']}, 'model_fn': {'values': ['basenjimod']}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'values': [128]}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 100}}}
# Create sweep with ID: recgvpoc
# Sweep URL: https://wandb.ai/toneyan/BASENJI_TRAINSET_THRESHOLD/sweeps/recgvpoc

# %% [markdown]
# # Peter's new stuff
# Sweep URL: https://wandb.ai/toneyan/NEW_MODELS_BASERES/sweeps/xc3ct52b

# %%
# # base resolution
# sweep_config = {
#     'method': 'grid'
#     }
# metric = {
#     'name': 'val_loss',
#     'goal': 'minimize'   
#     }
# sweep_config['metric'] = metric
# parameters_dict = {
#     'data_dir':{
#         'value':'datasets/complete/random_chop/i_3072_w_1'
#     },
#     'model_fn':{
#         'values': ['conv_profile_task_base',
#                   'residual_profile_task_base',
#                   'residual_profile_all_base']
#     },
#     'activation':{
#         'values': ['exponential', 'relu']
#     },
#     'loss_fn':{
#         'value':'poisson'
#     },
#     'window_size':{
#         'value': 2048
#     },
#     'bin_size':{
#         'value': 1
#     },
#     'l_rate': {
#         'value': 0.001
#     },
#     'num_epochs': {
#         'value': 100
#     },
#     'es_patience': {
#         'value': 10
#     },     
#     'lr_decay': {
#         'value': 0.2
#     }, 
#     'lr_patience': {
#         'value': 3
#     },
#     'rev_comp' : {
#         'value': True
#     },
#     'crop' : {
#         'value': 'r_crop'
#     }, 
    
# }
# sweep_config['parameters'] = parameters_dict
# print(sweep_config)
# sweep_id = wandb.sweep(sweep_config, project="NEW_MODELS_BASERES")

# 32 resolution
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'value':'datasets/complete/random_chop/i_3072_w_1'
#         'value':'/mnt/1a18a49e-9a31-4dbf-accd-3fb8abbfab2d/shush/4grid_atac/lite/random_chop/i_3072_w_1/'

    },
    'model_fn':{
        'values': ['conv_profile_all_dense_32',
                  'residual_profile_all_dense_32',
                  'conv_profile_task_conv_32',
                  'residual_profile_task_conv_32',
                  'conv_profile_task_base']
    },
    'activation':{
        'values': ['exponential', 'relu']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'value': 32
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    },
    'es_patience': {
        'value': 10
    },     
    'lr_decay': {
        'value': 0.2
    }, 
    'lr_patience': {
        'value': 3
    },
    'rev_comp' : {
        'value': True
    },
    'crop' : {
    'value': 'r_crop'
    }, 
    
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="NEW_MODELS_32")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': 'datasets/complete/random_chop/i_3072_w_1'}, 'model_fn': {'values': ['conv_profile_all_dense_32', 'residual_profile_all_dense_32', 'conv_profile_task_conv_32', 'residual_profile_task_conv_32', 'conv_profile_task_base']}, 'activation': {'values': ['exponential', 'relu']}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'value': 32}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 100}, 'es_patience': {'value': 10}, 'lr_decay': {'value': 0.2}, 'lr_patience': {'value': 3}, 'rev_comp': {'value': True}, 'crop': {'value': 'r_crop'}}}
# Create sweep with ID: wvuoaeyf
# Sweep URL: https://wandb.ai/toneyan/NEW_MODELS_32/sweeps/wvuoaeyf

# %% [markdown]
# # one baseres model crushed --> rerun here

# %%
# base resolution
sweep_config = {
    'method': 'grid'
    }
metric = {
    'name': 'val_loss',
    'goal': 'minimize'   
    }
sweep_config['metric'] = metric
parameters_dict = {
    'data_dir':{
        'value':'datasets/complete/random_chop/i_3072_w_1'
    },
    'model_fn':{
        'values': ['residual_profile_all_base']
    },
    'activation':{
        'values': ['relu']
    },
    'loss_fn':{
        'value':'poisson'
    },
    'window_size':{
        'value': 2048
    },
    'bin_size':{
        'value': 1
    },
    'l_rate': {
        'value': 0.001
    },
    'num_epochs': {
        'value': 100
    },
    'es_patience': {
        'value': 10
    },     
    'lr_decay': {
        'value': 0.2
    }, 
    'lr_patience': {
        'value': 3
    },
    'rev_comp' : {
        'value': True
    },
    'crop' : {
        'value': 'r_crop'
    }, 
    
}
sweep_config['parameters'] = parameters_dict
print(sweep_config)
sweep_id = wandb.sweep(sweep_config, project="NEW_MODELS_BASERES")
# Out:
# {'method': 'grid', 'metric': {'name': 'val_loss', 'goal': 'minimize'}, 'parameters': {'data_dir': {'value': 'datasets/complete/random_chop/i_3072_w_1'}, 'model_fn': {'values': ['residual_profile_all_base']}, 'activation': {'values': ['relu']}, 'loss_fn': {'value': 'poisson'}, 'window_size': {'value': 2048}, 'bin_size': {'value': 1}, 'l_rate': {'value': 0.001}, 'num_epochs': {'value': 100}, 'es_patience': {'value': 10}, 'lr_decay': {'value': 0.2}, 'lr_patience': {'value': 3}, 'rev_comp': {'value': True}, 'crop': {'value': 'r_crop'}}}
# Create sweep with ID: doc2czfg
# Sweep URL: https://wandb.ai/toneyan/NEW_MODELS_BASERES/sweeps/doc2czfg
