# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../scripts/')
import wandb_train
import utils
import tensorflow as tf

# %%
#train quantiative model
# !mkdir ../tutorial_outputs/
wandb_train.fit_robust('basenjimod', 'mse',
                       2048, 32, '../data/tfr_datasets/i_3072_w_1',
                       output_dir='../tutorial_outputs/',
                       config={'log_wandb':False, 'num_epochs':2})
# Out:
# mkdir: cannot create directory ‘../tutorial_outputs/’: File exists
# 2022-04-01 13:44:17.904364: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-01 13:44:18.391269: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14036 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:c1:00.0, compute capability: 8.6
# 2
# Using set of filter sizes for hyperparameter search
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  sequence (InputLayer)          [(None, 2048, 4)]    0           []
# ...

# %%
# train binary model
tf.keras.backend.clear_session()
# !mkdir ../tutorial_binary/
wandb_train.train_binary('residual_binary',data_dir = '../data/tfr_datasets/i_2048_binary/i_2048_binary.h5',
                       window_size = 2048,output_dir='../tutorial_binary/',
                       config={'log_wandb':False, 'num_epochs':2})
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 2048, 4)]    0           []
#
#  conv1d (Conv1D)                (None, 2048, 196)    14896       ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 2048, 196)   784         ['conv1d[0][0]']
#  alization)
#
#  conv_activation (Activation)   (None, 2048, 196)    0           ['batch_normalization[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 2048, 196)    115444      ['conv_activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 2048, 196)   784         ['conv1d_1[0][0]']
#  rmalization)
#
#  activation (Activation)        (None, 2048, 196)    0           ['batch_normalization_1[0][0]']
#
#  dropout (Dropout)              (None, 2048, 196)    0           ['activation[0][0]']
#
# ...
