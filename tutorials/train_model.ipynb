# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../scripts/')
import wandb_train
import utils

# %%
wandb_train.fit_robust('basenjimod', 'mse',
                       2048, 32, '../data/tfr_datasets/i_3072_w_1',
                       output_dir='tutorial_outputs',
                       config={'log_wandb':False, 'num_epochs':2})
# Out:
# 2
# Using set of filter sizes for hyperparameter search
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# sequence (InputLayer)           [(None, 2048, 4)]    0
# __________________________________________________________________________________________________
# gelu_7 (GELU)                   (None, 2048, 4)      0           sequence[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 2048, 128)    7680        gelu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 2048, 128)    512         conv1d_7[0][0]
# __________________________________________________________________________________________________
# ...
